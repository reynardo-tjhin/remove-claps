# %%
import pandas as pd

# %%
data = pd.read_csv("dataset.csv")

data
# Out:
#                                            audio_name  clap_start  clap_end  \
# 0   REMASTERED Yunchan Lim 임윤찬 – RACHMANINOV Piano...           0        11
# 1   Seong-Jin Cho – Piano Concerto in E minor Op 1...           0        21
# 2   BRUCE (XIAOYU) LIU – final round (18th Chopin ...           0        16
# 3   Tchaikovsky Piano Concerto No 1 FULL / Martha ...           0        14
# 4   TCHAIKOVSKY ~ Piano Concerto No. 1 in B-flat m...           0         4
# 5   Martha Argerich - Rachmaninov Piano Concerto N...          34        48
# 6   P. I. Tchaikovsky - Violin Concerto in D major...           5        39
# 7   Ray Chen Mendelssohn Violin Concerto in E mino...           0        15
# 8   Ray Chen SIBELIUS Violin Concerto in D minor O...           0        15
# 9   Janine Jansen - Mendelssohn Violin Concerto in...          15        19
# 10  David Oistrakh & Igor Oistrakh - Mozart Sinfon...           0        28
# ...

# %%
links = pd.read_csv("music_links.csv")

links
# Out:
#                                            audio_name  \
# 0   REMASTERED Yunchan Lim 임윤찬 – RACHMANINOV Piano...
# 1   Seong-Jin Cho – Piano Concerto in E minor Op 1...
# 2   BRUCE (XIAOYU) LIU – final round (18th Chopin ...
# 3   Tchaikovsky Piano Concerto No 1 FULL / Martha ...
# 4   TCHAIKOVSKY ~ Piano Concerto No. 1 in B-flat m...
# 5   Martha Argerich - Rachmaninov Piano Concerto N...
# 6   P. I. Tchaikovsky - Violin Concerto in D major...
# 7   Ray Chen Mendelssohn Violin Concerto in E mino...
# 8   Ray Chen SIBELIUS Violin Concerto in D minor O...
# 9   Janine Jansen - Mendelssohn Violin Concerto in...
# 10  David Oistrakh & Igor Oistrakh - Mozart Sinfon...
# 11  David Oistrakh - Brahms Violin Concerto in D M...
# 12  Yunchan Lim 임윤찬 – MOZART Piano Concerto No. 22...
# 13  Yunchan Lim 임윤찬 – LISZT 12 Transcendental Etud...
# 14  임윤찬-극락의 파리공연!!리스트Franz Liszt-Liebestraum No. 3...
# 15  Arthur Rubinstein Live Recital Warsaw 1966. Sc...
# ...

# %%
new_data = pd.read_csv("newdata.csv")

new_data
# Out:
#    audio_name  clap_start  clap_end  music_start  music_end  end_clap_start
# 0      audio0           0        11           32        NaN             NaN
# 1      audio1           0        21           34        NaN             NaN
# 2      audio2           0        16           41        NaN             NaN
# 3      audio3           0        14           35        NaN             NaN
# 4      audio4           0         4           13        NaN             NaN
# 5      audio5          34        48           60        NaN             NaN
# 6      audio6           5        39           49        NaN             NaN
# 7      audio7           0        15           20        NaN             NaN
# 8      audio8           0        15           31        NaN             NaN
# 9      audio9          15        19           32        NaN             NaN
# 10    audio10           0        28           64        NaN             NaN
# ...
