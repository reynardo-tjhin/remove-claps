# %%
import pandas as pd

# %%
data = pd.read_csv("../new_dataset.csv")

data
# Out:
#    audio_name  clap_start(s)  clap_end(s)  is_end  to_train
# 0      audio0           0.00        11.20       0         1
# 1      audio0        2552.10      2601.50       1         1
# 2      audio1           0.00        22.60       0         1
# 3      audio1        2419.60      2451.75       1         1
# 4      audio2           0.00        17.40       0         0
# 5      audio2        2417.05      2488.09       1         0
# 6      audio3           0.00        15.20       0         1
# 7      audio3        2017.80      2096.62       1         1
# 8      audio4           0.00         5.40       0         0
# 9      audio4        1256.65      1284.40       0         0
# 10     audio4        2128.18      2191.20       1         0
# 11     audio5          34.00        49.55       0         0
# 12     audio5        2480.60      2546.00       1         0
# 13     audio6           5.50        40.60       0         1
# 14     audio6        1161.60      1186.20       0         1
# ...

# %%
links = pd.read_csv("../music_links.csv")

links
# Out:
#                                            audio_name  \
# 0   REMASTERED Yunchan Lim 임윤찬 – RACHMANINOV Piano...
# 1   Seong-Jin Cho – Piano Concerto in E minor Op 1...
# 2   BRUCE (XIAOYU) LIU – final round (18th Chopin ...
# 3   Tchaikovsky Piano Concerto No 1 FULL / Martha ...
# 4   TCHAIKOVSKY ~ Piano Concerto No. 1 in B-flat m...
# 5   Martha Argerich - Rachmaninov Piano Concerto N...
# 6   P. I. Tchaikovsky - Violin Concerto in D major...
# 7   Ray Chen Mendelssohn Violin Concerto in E mino...
# 8   Ray Chen SIBELIUS Violin Concerto in D minor O...
# 9   Janine Jansen - Mendelssohn Violin Concerto in...
# 10  David Oistrakh & Igor Oistrakh - Mozart Sinfon...
# 11  David Oistrakh - Brahms Violin Concerto in D M...
# 12  Yunchan Lim 임윤찬 – MOZART Piano Concerto No. 22...
# 13  Yunchan Lim 임윤찬 – LISZT 12 Transcendental Etud...
# 14        Yunchan Lim - F. Liszt : Liebestraume No. 3
# 15  Arthur Rubinstein Live Recital Warsaw 1966. Sc...
# ...

# %%
# only after building the features
data_with_features = pd.read_csv("../data/data.csv")

data_with_features
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/reynardo/PROGRAMMING/remove-claps/notebooks/data-display.ipynb Cell 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/reynardo/PROGRAMMING/remove-claps/notebooks/data-display.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> # only after building the features
# ----> <a href='vscode-notebook-cell:/home/reynardo/PROGRAMMING/remove-claps/notebooks/data-display.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> data_with_features = pd.read_csv("../data/data.csv")
#       <a href='vscode-notebook-cell:/home/reynardo/PROGRAMMING/remove-claps/notebooks/data-display.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> data_with_features
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
# ...

# %%
# only after training
training_output = pd.read_csv("../src/models/train_result.csv")

training_output
# Out:
#                             Model  Accuracy (Train)  Accuracy (Test)  \
# 0                             SVC          0.991674         0.985847
# 1            ExtraTreesClassifier          1.000000         0.973375
# 2      LinearDiscriminantAnalysis          0.976316         0.975847
# 3          DecisionTreeClassifier          1.000000         0.984187
# 4            KNeighborsClassifier          0.993987         0.991680
# 5          RandomForestClassifier          1.000000         0.989174
# 6                   MLPClassifier          0.998335         0.993347
# 7              AdaBoostClassifier          1.000000         0.986674
# 8                           NuSVC          0.957905         0.953368
# 9                      GaussianNB          0.925340         0.926722
# 10  QuadraticDiscriminantAnalysis          0.978166         0.976674
#
#     F1 (Train)  F1 (Test)  Precision (Train)  Precision (Test)  \
# 0     0.994047   0.989790           0.988295          0.988135
# ...
