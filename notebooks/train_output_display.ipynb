# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
# only after training
training_output = pd.read_csv("../src/models/train_result.csv")
training_output.sort_values(by='Accuracy (Test)').style.background_gradient(cmap=plt.cm.Blues)
# Out:
# <style type="text/css">
# #T_6a7b7_row0_col1, #T_6a7b7_row0_col2, #T_6a7b7_row0_col3, #T_6a7b7_row0_col4, #T_6a7b7_row0_col5, #T_6a7b7_row0_col7, #T_6a7b7_row0_col8, #T_6a7b7_row1_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6a7b7_row0_col6 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_6a7b7_row1_col1 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_6a7b7_row1_col2 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_6a7b7_row1_col3 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_6a7b7_row1_col4 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_6a7b7_row1_col5 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_6a7b7_row1_col7 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_6a7b7_row1_col8 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_6a7b7_row2_col1 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_6a7b7_row2_col2 {
#   background-color: #6caed6;
# ...
